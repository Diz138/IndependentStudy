# %%
# !pip install C:\Users\mattd\PyICU-2.4.3-cp37-cp37m-win_amd64.whl
# !pip install C:\Users\mattd\pycld2-0.41-cp37-cp37m-win_amd64.whl
# Out:
# ERROR: PyICU-2.4.3-cp37-cp37m-win_amd64.whl is not a supported wheel on this platform.
# ERROR: pycld2-0.41-cp37-cp37m-win_amd64.whl is not a supported wheel on this platform.

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.5

# %%
# !pip install C:\Users\mattd\PyICU-2.6-cp38-cp38-win_amd64.whl
# !pip install C:\Users\mattd\pycld2-0.41-cp38-cp38-win_amd64.whl
# Out:
# Processing c:\users\mattd\pyicu-2.6-cp38-cp38-win_amd64.whl
# ...
# Processing c:\users\mattd\pycld2-0.41-cp38-cp38-win_amd64.whl
# ...

# %%
# !pip install morfessor
# Out:
# ...
#   Using cached Morfessor-2.0.6-py3-none-any.whl (35 kB)
# ...

# %%
import polyglot

# %%
from polyglot.text import Text, Word

# %%
from polyglot.downloader import downloader
downloader.download("embeddings2.de")
downloader.download("ner2.de")
# Out:
# [polyglot_data] Downloading package embeddings2.de to
# [polyglot_data]     C:\Users\mattd\AppData\Roaming\polyglot_data...
# [polyglot_data]   Package embeddings2.de is already up-to-date!
# [polyglot_data] Downloading package ner2.de to
# [polyglot_data]     C:\Users\mattd\AppData\Roaming\polyglot_data...
# [polyglot_data]   Package ner2.de is already up-to-date!
# True

# %%
  
text = Text(u"Google is an American multinational technology company and Sundar Pichai is the CEO of Google") 
print(text.entities)
# Out:
# [I-ORG(['Google']), I-LOC(['American']), I-PER(['Sundar', 'Pichai']), I-ORG(['Google'])]

# %%
from polyglot.downloader import downloader
downloader.download("TASK:embeddings2")
# Out:
# [polyglot_data] Downloading collection 'TASK:embeddings2'
# [polyglot_data]    |
# [polyglot_data]    | Downloading package embeddings2.pam to
# [polyglot_data]    |     C:\Users\mattd\AppData\Roaming\polyglot_data.
# [polyglot_data]    |     ..
# [polyglot_data]    |   Package embeddings2.pam is already up-to-date!
# [polyglot_data]    | Downloading package embeddings2.it to
# [polyglot_data]    |     C:\Users\mattd\AppData\Roaming\polyglot_data.
# [polyglot_data]    |     ..
# [polyglot_data]    |   Package embeddings2.it is already up-to-date!
# [polyglot_data]    | Downloading package embeddings2.hsb to
# [polyglot_data]    |     C:\Users\mattd\AppData\Roaming\polyglot_data.
# [polyglot_data]    |     ..
# [polyglot_data]    |   Package embeddings2.hsb is already up-to-date!
# [polyglot_data]    | Downloading package embeddings2.sah to
# [polyglot_data]    |     C:\Users\mattd\AppData\Roaming\polyglot_data.
# [polyglot_data]    |     ..
# ...

# %%
downloader.download("TASK:ner2")
# Out:
# [polyglot_data] Downloading collection 'TASK:ner2'
# [polyglot_data]    |
# [polyglot_data]    | Downloading package ner2.it to
# [polyglot_data]    |     C:\Users\mattd\AppData\Roaming\polyglot_data.
# [polyglot_data]    |     ..
# [polyglot_data]    |   Package ner2.it is already up-to-date!
# [polyglot_data]    | Downloading package ner2.hi to
# [polyglot_data]    |     C:\Users\mattd\AppData\Roaming\polyglot_data.
# [polyglot_data]    |     ..
# [polyglot_data]    |   Package ner2.hi is already up-to-date!
# [polyglot_data]    | Downloading package ner2.fr to
# [polyglot_data]    |     C:\Users\mattd\AppData\Roaming\polyglot_data.
# [polyglot_data]    |     ..
# [polyglot_data]    |   Package ner2.fr is already up-to-date!
# [polyglot_data]    | Downloading package ner2.es to
# [polyglot_data]    |     C:\Users\mattd\AppData\Roaming\polyglot_data.
# [polyglot_data]    |     ..
# [polyglot_data]    |   Package ner2.es is already up-to-date!
# ...

# %%
text = Text("My name is Amelia") 
print(text.entities)
# Out:
# [I-PER(['Amelia'])]

# %%
pip install -U textblob
# Out:
# Requirement already up-to-date: textblob in c:\users\mattd\anaconda3\lib\site-packages (0.15.3)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
python -m textblob.download_corpora
# Out:
#   File "<ipython-input-9-bec4ba3f7ac1>", line 1
#     python -m textblob.download_corpora
#               ^
# SyntaxError: invalid syntax

# %%
from textblob import TextBlob

text = 'The titular threat of The Blob has always struck me as the ultimate movie'

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mattd\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\mattd\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
wiki = TextBlob("Python is a high-level, general-purpose programming language.")
wiki.tags
# Out:
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN')]

# %%
import pandas as pd
d = {'textNumber': [1, 2], 'body2': ["Hi Madeleine. This is your neighbor John on Bare Hill Road. I am texting you to see if you can pick up my kids May and Mark from Littleton Elementary today at 6. I am a doctor at Children's Hospital in Boston and have to perform a surgery today. I think that 978-888-584 is your number, so if this is not it then I am sorry for whoever this is. If the school asks you what their IDs are Mark’s is 1111 and May’s is 9999. Thank you Madeline.", "Sup bro it is Dave. I been lookin at your story and you accidentally posted yo SSN 999999999 on it my man. WTF dude that aint no smart move cuz people can find it n thats not gr8 fo you Davio."]}
df1 = pd.DataFrame(data=d)

d2 = {'textNumber': [1, 2], 'body2': ["Hi Madeleine. This is your neighbor John on Bare Hill Road. I am texting you to see if you can pick up my kids May and Mark from Littleton Elementary today at 6. I am a doctor at Children's Hospital in Boston and have to perform a surgery today. I think that 978-888-584 is your number, so if this is not it then I am sorry for whoever this is. If the school asks you what their IDs are Mark’s is 1111 and May’s is 9999. Thank you Madeline.", "Sup bro it is Dave. I been lookin at your story and you accidentally posted yo SSN 999999999 on it my man. WTF dude that aint no smart move cuz people can find it n thats not gr8 fo you Davio."]}
df2 = pd.DataFrame(data=d2)

for ind in df2.index: 
     print(df2['textNumber'][ind], ":  ", df2['body2'][ind], "\n")

for ind in df2.index: 
    text = Text(df2['body2'][ind]) 
    wiki = TextBlob(df2['body2'][ind])
    for tup in wiki.tags:
        if tup[1] == 'CD':
            print(tup[0])
    #print(df2['textNumber'][ind], ":  ", text.entities, "\n", wiki.tags, "\n")
# Out:
# 1 :   Hi Madeleine. This is your neighbor John on Bare Hill Road. I am texting you to see if you can pick up my kids May and Mark from Littleton Elementary today at 6. I am a doctor at Children's Hospital in Boston and have to perform a surgery today. I think that 978-888-584 is your number, so if this is not it then I am sorry for whoever this is. If the school asks you what their IDs are Mark’s is 1111 and May’s is 9999. Thank you Madeline.
#
# 2 :   Sup bro it is Dave. I been lookin at your story and you accidentally posted yo SSN 999999999 on it my man. WTF dude that aint no smart move cuz people can find it n thats not gr8 fo you Davio.
#
# 6
# 978-888-584
# 1111
# 9999
# 999999999

# %%
from textblob import Word
spell_Test = "Sup bro it is Dave. I been lookin at your story and you accidentally posted yo SSN 999999999 on it my man. WTF dude that aint no smart move cuz people can find it n thats not gr8 fo you Davio."
for words in spell_Test.split():
    w = Word(words)
    print(w.spellcheck())
# Out:
# [('Up', 0.9883167459974037), ('Cup', 0.01125054089138901), ('Sup', 0.00043271311120726956)]
# [('brow', 0.4666666666666667), ('fro', 0.35555555555555557), ('pro', 0.15555555555555556), ('br', 0.022222222222222223)]
# [('it', 1.0)]
# [('is', 1.0)]
# [('Have', 0.8267455621301775), ('Gave', 0.10461538461538461), ('Save', 0.02603550295857988), ('Saved', 0.012071005917159764), ('Haven', 0.009230769230769232), ('Waved', 0.006863905325443787), ('Wave', 0.006153846153846154), ('Waves', 0.00378698224852071), ('Paved', 0.0007100591715976331), ('Cave', 0.0007100591715976331), ('Avec', 0.0007100591715976331), ('Waver', 0.00023668639053254438), ('Tavel', 0.00023668639053254438), ('Saves', 0.00023668639053254438), ('Raven', 0.00023668639053254438), ('Raved', 0.00023668639053254438), ('Eaves', 0.00023668639053254438), ('Dave', 0.00023668639053254438), ('Caved', 0.00023668639053254438), ('Avez', 0.00023668639053254438), ('Ave', 0.00023668639053254438)]
# [('I', 1.0)]
# [('been', 1.0)]
# ...

# %%
import pandas as pd
d = {'textNumber': [1, 2], 'body2': ["Hi Madeleine. This is your neighbor John on Bare Hill Road. I am texting you to see if you can pick up my kids May and Mark from Littleton Elementary today at 6. I am a doctor at Children's Hospital in Boston and have to perform a surgery today. I think that 978-888-584 is your number, so if this is not it then I am sorry for whoever this is. If the school asks you what their IDs are Mark’s is 1111 and May’s is 9999. Thank you Madeline.", "Sup bro it is Dave. I been lookin at your story and you accidentally posted yo SSN 999999999 on it my man. WTF dude that aint no smart move cuz people can find it n thats not gr8 fo you Davio."]}
df1 = pd.DataFrame(data=d)

d2 = {'textNumber': [1, 2], 'body2': ["It is not acceptible to adquire that equiptment with such ignorence cuz becomeing desparate is a dilema in of itself. Ao wut I am tryna say is Missisdipi is the worst, n so is WPI since it has towns like Boxford w students who go to Masco. There are not many Alaskan Native kids who are Muslim which is really sad. ", "My fav combo of numbers and letters is Sparky14. Sparky was fourteen when he died, so that is what a bunch of my passwords are. Technically he was 14.6 years old, but who is counting anyways. He died on 2/10/2020 which can also be written as February 10th, 2020."]}
df2 = pd.DataFrame(data=d2)



for ind in df2.index: 
    text = Text(df2['body2'][ind]) 
    wiki = TextBlob(df2['body2'][ind])
    print(df2['textNumber'][ind], ":  ", text.entities, "\n", wiki.tags, "\n")

for words in df2['body2'][0].split():
    w = Word(words)
    print(w.spellcheck())
# Out:
# 1 :   []
# ...

# %%
import pandas as pd
d = {'textNumber': [1, 2], 'body2': ["Hi Madeleine. This is your neighbor John on Bare Hill Road. I am texting you to see if you can pick up my kids May and Mark from Littleton Elementary today at 6. I am a doctor at Children's Hospital in Boston and have to perform a surgery today. I think that 978-888-584 is your number, so if this is not it then I am sorry for whoever this is. If the school asks you what their IDs are Mark’s is 1111 and May’s is 9999. Thank you Madeline.", "Sup bro it is Dave. I been lookin at your story and you accidentally posted yo SSN 999999999 on it my man. WTF dude that aint no smart move cuz people can find it n thats not gr8 fo you Davio."]}
df1 = pd.DataFrame(data=d)

d2 = {'textNumber': [1, 2],'body2': ['NBC Boston is my favorite network that wpi offers. In order to subscribe to the network though,you have to go to https://en.wikipedia.org/wiki/List_of_the_most_common_passwords and login. In order to login I have my username as mcdzwil@wpi.edu and qwerty25 as my password.', 'I think the order has to be: ME, MA, and KY. Also, Danvers and Beverly are having some trouble handling it. I live 30 minutes from metrorock so it might be a bit til I get there. There are many cities with it though so. I got class though right now so Ill brb. CWYL. T']}
df2 = pd.DataFrame(data=d2)



for ind in df2.index: 
    text = Text(df2['body2'][ind]) 
    wiki = TextBlob(df2['body2'][ind])
    print(df2['textNumber'][ind], ":  ", text.entities, "\n", wiki.tags, "\n")

for words in df2['body2'][0].split():
    w = Word(words)
    print(w.spellcheck())
# Out:
# 1 :   [I-ORG(['NBC', 'Boston'])]
#  [('NBC', 'NNP'), ('Boston', 'NNP'), ('is', 'VBZ'), ('my', 'PRP$'), ('favorite', 'JJ'), ('network', 'NN'), ('that', 'WDT'), ('wpi', 'VBZ'), ('offers', 'NNS'), ('In', 'IN'), ('order', 'NN'), ('to', 'TO'), ('subscribe', 'VB'), ('to', 'TO'), ('the', 'DT'), ('network', 'NN'), ('though', 'IN'), ('you', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('go', 'VB'), ('to', 'TO'), ('https', 'VB'), ('//en.wikipedia.org/wiki/List_of_the_most_common_passwords', 'NNS'), ('and', 'CC'), ('login', 'NN'), ('In', 'IN'), ('order', 'NN'), ('to', 'TO'), ('login', 'VB'), ('I', 'PRP'), ('have', 'VBP'), ('my', 'PRP$'), ('username', 'JJ'), ('as', 'IN'), ('mcdzwil', 'NN'), ('@', 'NNP'), ('wpi.edu', 'NN'), ('and', 'CC'), ('qwerty25', 'NN'), ('as', 'IN'), ('my', 'PRP$'), ('password', 'NN')]
#
# 2 :   [I-LOC(['KY']), I-LOC(['Danvers']), I-PER(['Beverly'])]
# ...

# %%
import pandas as pd

d2 = {'textNumber': [1],'body2': ['Spelling mistakes might hinder this program like Taeewan or Rngland. Along with this, I will be going to the rr tonight if you wanna join. There are not a lot of white people especially mormons so I wonder how that will be since we are from utag.']} 
df2 = pd.DataFrame(data=d2)



for ind in df2.index: 
    text = Text(df2['body2'][ind]) 
    wiki = TextBlob(df2['body2'][ind])
    print(df2['textNumber'][ind], ":  ", text.entities, "\n", wiki.tags, "\n")
# Out:
# 1 :   []
#  [('Spelling', 'VBG'), ('mistakes', 'NNS'), ('might', 'MD'), ('hinder', 'VB'), ('this', 'DT'), ('program', 'NN'), ('like', 'IN'), ('Taeewan', 'NNP'), ('or', 'CC'), ('Rngland', 'NNP'), ('Along', 'IN'), ('with', 'IN'), ('this', 'DT'), ('I', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('going', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('rr', 'NN'), ('tonight', 'NN'), ('if', 'IN'), ('you', 'PRP'), ('wan', 'VBP'), ('na', 'JJ'), ('join', 'NN'), ('There', 'EX'), ('are', 'VBP'), ('not', 'RB'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('white', 'JJ'), ('people', 'NNS'), ('especially', 'RB'), ('mormons', 'NNS'), ('so', 'IN'), ('I', 'PRP'), ('wonder', 'VBP'), ('how', 'WRB'), ('that', 'DT'), ('will', 'MD'), ('be', 'VB'), ('since', 'IN'), ('we', 'PRP'), ('are', 'VBP'), ('from', 'IN'), ('utag', 'JJ')]

# %%
import pandas as pd

d2 = {'textNumber': [1],'body2': ['There is this little company wah that has a base on kiliman. This is in tz which has my favorite: sign industries. However, that is nothing compared to the l memorial in washington d.c.']} 
df2 = pd.DataFrame(data=d2)



for ind in df2.index: 
    text = Text(df2['body2'][ind]) 
    wiki = TextBlob(df2['body2'][ind])
    print(df2['textNumber'][ind], ":  ", text.entities, "\n", wiki.tags, "\n")
# Out:
# 1 :   [I-LOC(['tz']), I-LOC(['washington'])]
#  [('There', 'EX'), ('is', 'VBZ'), ('this', 'DT'), ('little', 'JJ'), ('company', 'NN'), ('wah', 'NN'), ('that', 'WDT'), ('has', 'VBZ'), ('a', 'DT'), ('base', 'NN'), ('on', 'IN'), ('kiliman', 'NN'), ('This', 'DT'), ('is', 'VBZ'), ('in', 'IN'), ('tz', 'NN'), ('which', 'WDT'), ('has', 'VBZ'), ('my', 'PRP$'), ('favorite', 'JJ'), ('sign', 'NN'), ('industries', 'NNS'), ('However', 'RB'), ('that', 'DT'), ('is', 'VBZ'), ('nothing', 'NN'), ('compared', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('l', 'NN'), ('memorial', 'NN'), ('in', 'IN'), ('washington', 'NN'), ('d.c', 'NN')]

# %%
import pandas as pd

d2 = {'textNumber': [1],'body2': ['WPI']} 
df2 = pd.DataFrame(data=d2)



for ind in df2.index: 
    text = Text(df2['body2'][ind]) 
    wiki = TextBlob(df2['body2'][ind])
    print(df2['textNumber'][ind], ":  ", text.entities, "\n", wiki.tags, "\n")
# Out:
# 1 :   [I-PER(['WPI'])]
#  [('WPI', 'NN')]

# %%
conda install doccano
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - doccano
#
# Current channels:
#
#   - http://conda.anaconda.org/gurobi/win-64
#   - http://conda.anaconda.org/gurobi/noarch
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
# ...
